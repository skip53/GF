# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
% matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir('/Users/lin/Desktop')

# %%
df = pd.read_excel('glass fiber content test.xlsx',sheetname=1,header=0)

# %%
df
# Out:
#    Content  Breakage  Percent  Type
# 0        酸    1069.6    24.70  南京天元
# 1        酸    1204.3    23.35  南京天元
# 2        酸    1122.0    23.55  南京天元
# 3        酸    1201.7    25.00  南京天元
# 4        碱    1064.0    24.25  南京天元
# 5        碱    1104.0    23.05  南京天元
# 6        碱    1093.9    22.85  南京天元
# 7        碱    1056.9    29.35  南京天元
# 8        氧     822.8    18.90  南京天元
# 9        氧     879.6    18.25  南京天元
# 10       氧     935.0    19.60  南京天元
# 11       氧     924.5    18.55  南京天元
# 12       折    1099.6    22.95  南京天元
# 13       折    1168.4    24.35  南京天元
# 14       折    1147.4    22.00  南京天元
# 15       折    1073.6    23.47  南京天元
# 16       空    1216.0    22.85  南京天元
# 17       空    1139.6    25.15  南京天元
# 18       空    1234.2    23.25  南京天元
# 19       空    1287.0    22.10  南京天元
# 20       温    1169.9    49.00  南京天元
# 21       温    1235.7    46.20  南京天元
# 22       温    1265.6    47.40  南京天元
# 23       温    1270.6    42.30  南京天元
# 24       酸     912.6    27.60  四川华源
# ...

# %%
print(len(df))
# Out:
# 48

# %%
df['Type'].value_counts()
# Out:
# 四川华源    24
# 南京天元    24
# Name: Type, dtype: int64

# %%
df['Content'].value_counts()
# Out:
# 酸    8
# 空    8
# 温    8
# 折    8
# 氧    8
# 碱    8
# Name: Content, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Content', 'Breakage', 'Percent', 'Type']

# %%
data = df[['Type','Breakage','Percent','Content']]

# %%
sns.barplot(x='Type',y='Breakage',data=data,hue='Type')

# %%
sns.barplot(x= 'Content',y = 'Breakage',hue = 'Type',data=data)

# %%
data_blank = data[data['Content']=='空']
data_acid = data[data['Content']=='酸']
data_alkali = data[data['Content']=='碱']
data_oxidation = data[data['Content']=='氧']
data_fold = data[data['Content']=='折']
data_temp = data[data['Content']=='温']
# data_blank、data_acid、data_alkali、data_oxidation、data_fold、data_temp

# %%
data_blank['seq']=['1','2','3','4']*2
data_acid['seq']=['1','2','3','4']*2
data_alkali['seq']=['1','2','3','4']*2
data_oxidation['seq']=['1','2','3','4']*2
data_fold['seq']=['1','2','3','4']*2
data_temp['seq']=['1','2','3','4']*2

# %%
# data_female = data[data['gender'] == '女']
data_blank = data[data['Content']=='空']
data44 = data_blank[data_blank['Type']=='南京天元']
data44
# Out:
#     Type  Breakage  Percent Content
# 16  南京天元    1216.0    22.85       空
# 17  南京天元    1139.6    25.15       空
# 18  南京天元    1234.2    23.25       空
# 19  南京天元    1287.0    22.10       空

# %%
# combined_train_test['Group_Ticket'] = 
# combined_train_test['Fare'].groupby(by=combined_train_test['Ticket']).transform('count')
# fare_survived = train_data['Fare'][train_data['Survived'] == 1]
data_nk = data[data['Content']=='空'][data['Type']=='南京天元']
data_nw = data[data['Content']=='温'][data['Type']=='南京天元']
data_ns = data[data['Content']=='酸'][data['Type']=='南京天元']
data_nj = data[data['Content']=='碱'][data['Type']=='南京天元']
data_ny = data[data['Content']=='氧'][data['Type']=='南京天元']
data_nz = data[data['Content']=='折'][data['Type']=='南京天元']
data_sk = data[data['Content']=='空'][data['Type']=='四川华源']
data_sw = data[data['Content']=='温'][data['Type']=='四川华源']
data_ss = data[data['Content']=='酸'][data['Type']=='四川华源']
data_sj = data[data['Content']=='碱'][data['Type']=='四川华源']
data_sy = data[data['Content']=='氧'][data['Type']=='四川华源']
data_sz = data[data['Content']=='折'][data['Type']=='四川华源']

# %%
data_nk['Breakage'].mean()
data_nw['Breakage'].mean()
data_ns['Breakage'].mean()
data_nj['Breakage'].mean()
data_ny['Breakage'].mean()
data_nz['Breakage'].mean()
data_ny['Breakage'].mean()
data_nz['Breakage'].mean()
data_sk['Breakage'].mean()
data_sw['Breakage'].mean()
data_ss['Breakage'].mean()
data_sj['Breakage'].mean()
data_sy['Breakage'].mean()
data_sz['Breakage'].mean()
# Out:
# 956.35

# %%
mean_value = pd.Series(data = [data_nk['Breakage'].mean(),
data_nw['Breakage'].mean(),
data_ns['Breakage'].mean(),
data_nj['Breakage'].mean(),
data_ny['Breakage'].mean(),
data_nz['Breakage'].mean(),
data_sk['Breakage'].mean(),
data_sw['Breakage'].mean(),
data_ss['Breakage'].mean(),
data_sj['Breakage'].mean(),
data_sy['Breakage'].mean(),
data_sz['Breakage'].mean()],name = 'Value')
mean_value
# Out:
# 0     1219.200
# 1     1235.450
# 2     1149.400
# 3     1079.700
# 4      890.475
# 5     1122.250
# 6     1223.700
# 7     1126.500
# 8      895.100
# 9      807.975
# 10     692.925
# 11     956.350
# Name: Value, dtype: float64

# %%
mean_value['index'] = ['空', '温','酸', '碱', '氧', '折' ]*2
mean_value1 = pd.DataFrame(mean_value)
mean_n = mean_value1[:6]
mean_n
mean_na = mean_n['Value']/1219.2*100
mean_n['Retention'] = mean_na
mean_n['Content'] = ['空', '温','酸', '碱', '氧', '折' ]
mean_n
# Out:
#      Value Retention Content
# 0   1219.2       100       空
# 1  1235.45   101.333       温
# 2   1149.4   94.2749       酸
# 3   1079.7   88.5581       碱
# 4  890.475   73.0376       氧
# 5  1122.25   92.0481       折

# %%
plt.figure(figsize = (9,6))
ax1=sns.barplot('Content','Retention',hue='Content',data= mean_n,palette='RdBu_r')
plt.grid(linestyle='--')
plt.xlabel('南京天元',fontsize = 18)
plt.ylabel('保留率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.savefig('南京天元.jpg',dpi=400)

# %%
mean_value1
mean_s = mean_value1[6:12]
mean_sa = mean_s['Value']/1119.2*100
mean_s['Retention'] = mean_sa
mean_s['Content'] = ['空', '温','酸', '碱', '氧', '折' ]
mean_s
# Out:
#       Value Retention Content
# 6    1223.7   109.337       空
# 7    1126.5   100.652       温
# 8     895.1   79.9768       酸
# 9   807.975   72.1922       碱
# 10  692.925   61.9125       氧
# 11   956.35   85.4494       折

# %%
plt.figure(figsize = (9,6))
ax1=sns.barplot('Content','Retention',hue='Content',data= mean_s,palette='RdBu_r')
plt.grid(linestyle='--')
plt.xlabel('四川华源',fontsize = 18)
plt.ylabel('保留率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.savefig('四川华源.jpg',dpi=400)

# %%
plt.figure(figsize = (9,6))
ax=sns.barplot('Content','Retention',hue='Content',data= mean_s,palette='binary_r')
plt.grid(linestyle='--')
plt.xlabel('四川华源',fontsize = 18)
plt.ylabel('保留率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax.legend(fontsize = 12)

# %%
data['Content'].unique().tolist()
# ['空', '温','酸', '碱', '氧', '折' ]
# Out:
# ['酸', '碱', '氧', '折', '空', '温']

# %%
# user_info["height"] = ["178", "168", "178", "180cm"]
data_blank['seq']=['1','2','3','4']*2

# data_blank.loc[row_indexer] = ['1','2','3','4','5','6','7','8']
# data_blank.order['seq','Content','Breakage','Percent','Tpye']
data_blank
# Out:
#     Type  Breakage  Percent Content seq
# 16  南京天元    1216.0    22.85       空   1
# 17  南京天元    1139.6    25.15       空   2
# 18  南京天元    1234.2    23.25       空   3
# 19  南京天元    1287.0    22.10       空   4
# 40  四川华源    1267.1    29.80       空   1
# 41  四川华源    1223.7    30.05       空   2
# 42  四川华源    1148.9    29.05       空   3
# 43  四川华源    1255.1    30.05       空   4

# %%
#空白样
plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Breakage',hue='Type',data=data_blank,palette="Set2")
plt.xlabel('空白组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,1500)
# plt.savefig('空白组_N.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Percent',hue='Type',data=data_blank,palette="Set1")
plt.xlabel('空白组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,35)
# plt.savefig('空白组_P.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Breakage',hue='Type',data=data_blank,palette="Set2")
plt.xlabel('空白组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('空白组_N2.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Percent',hue='Type',data=data_blank,palette="Set1")
plt.xlabel('空白组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('空白组_P2.jpg',dpi=400)

# %%
#酸组    data_blank、data_acid、data_alkali、data_oxidation、data_fold、data_temp
plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Breakage',hue='Type',data=data_acid,palette="Set2")
plt.xlabel('耐酸组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,1500)
# plt.savefig('耐酸组_N.jpg',dpi=400)


plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Percent',hue='Type',data=data_acid,palette="Set1")
plt.xlabel('耐酸组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,35)
# plt.savefig('耐酸组_P.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Breakage',hue='Type',data=data_acid,palette="Set2")
plt.xlabel('耐酸组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('耐酸组_N2.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Percent',hue='Type',data=data_acid,palette="Set1")
plt.xlabel('耐酸组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('耐酸组_P2.jpg',dpi=400)

# %%
#碱组     data_blank、data_acid、data_alkali、data_oxidation、data_fold、data_temp
plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Breakage',hue='Type',data=data_alkali,palette="Set2")
plt.xlabel('耐碱组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,1300)
# plt.savefig('耐碱组_N.jpg',dpi=400)


plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Percent',hue='Type',data=data_alkali,palette="Set1")
plt.xlabel('耐碱组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,35)
# plt.savefig('耐碱组_P.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Breakage',hue='Type',data=data_alkali,palette="Set2")
plt.xlabel('耐碱组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('耐碱组_N2.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Percent',hue='Type',data=data_alkali,palette="Set1")
plt.xlabel('耐碱组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('耐碱组_P2.jpg',dpi=400)

# %%
#氧组    data_blank、data_acid、data_alkali、data_oxidation、data_fold
plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Breakage',hue='Type',data=data_oxidation,palette="Set2")
plt.xlabel('耐氧组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,1100)
# plt.savefig('耐氧组_N.jpg',dpi=400)


plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Percent',hue='Type',data=data_oxidation,palette="Set1")
plt.xlabel('耐氧组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,25)
# plt.savefig('耐氧组_P.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Breakage',hue='Type',data=data_oxidation,palette="Set2")
plt.xlabel('耐氧组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('耐氧组_N2.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Percent',hue='Type',data=data_oxidation,palette="Set1")
plt.xlabel('耐氧组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,25)
# plt.savefig('耐氧组_P2.jpg',dpi=400)
# Out:
# (0, 25)

# %%
#温组    data_blank、data_acid、data_alkali、data_oxidation、data_fold、data_temp
plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Breakage',hue='Type',data=data_temp,palette="Set2")
plt.xlabel('耐温组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,1400)
# plt.savefig('耐温组_N.jpg',dpi=400)


plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Percent',hue='Type',data=data_temp,palette="Set1")
plt.xlabel('耐温组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('耐温组_P.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Breakage',hue='Type',data=data_temp,palette="Set2")
plt.xlabel('耐温组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('耐温组_N2.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Percent',hue='Type',data=data_temp,palette="Set1")
plt.xlabel('耐温组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('耐温组_P2.jpg',dpi=400)

# %%
# train_data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar()
data_blank[['Breakage','Type']].groupby(['Type']).mean().plot.bar()

# %%
#折组    data_blank、data_acid、data_alkali、data_oxidation、data_fold
plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Breakage',hue='Type',data=data_fold,palette="Set2")
plt.xlabel('耐折组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,1300)
# plt.savefig('耐折组_N.jpg',dpi=400)


plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Percent',hue='Type',data=data_fold,palette="Set1")
plt.xlabel('耐折组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,30)
# plt.savefig('耐折组_P.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Breakage',hue='Type',data=data_fold,palette="Set2")
plt.xlabel('耐折组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('耐折组_N2.jpg',dpi=400)

plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('Type','Percent',hue='Type',data=data_fold,palette="Set1")
plt.xlabel('耐折组',fontsize = 18)
plt.ylabel('断裂伸长率',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
# plt.savefig('耐折组_P2.jpg',dpi=400)

# %%
# plt.axvline(hmean_male,color='y',linestyle=":",alpha=0.8) 
# plt.text(hmean_male+2,0.005,'male_height_mean: %.1fcm' % (hmean_male), color = 'y')
# # 绘制男运动员平均身高辅助线

# %%
# fig, ax = plt.subplots(1, 2, figsize = (18, 8))
# sns.violinplot("Pclass", "Age", hue="Survived", data=train_data, split=True, ax=ax[0])
# ax[0].set_title('Pclass and Age vs Survived')
# ax[0].set_yticks(range(0, 110, 10))

# sns.violinplot("Sex", "Age", hue="Survived", data=train_data, split=True, ax=ax[1])
# ax[1].set_title('Sex and Age vs Survived')
# ax[1].set_yticks(range(0, 110, 10))

# plt.show()

fig,ax = plt.subplots(1,2,figsize = (18,6))

sns.barplot('Type','Breakage',hue='Type',data=data_blank,ax=ax[0])
ax[0].legend(fontsize=20)
plt.xlabel('空白组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)

sns.barplot('Type','Percent',hue = 'Type',data=data_blank,ax=ax[1])
plt.xlabel('空白组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax[1].legend(fontsize=20)

# %%
plt.figure(figsize=(8,5))
ax1 = sns.swarmplot('seq','Breakage',hue='Type',data=data_blank)

# %%
data_fold
# Out:
#    Type  Breakage  Percent
# 12    折    1099.6    22.95
# 13    折    1168.4    24.35
# 14    折    1147.4    22.00
# 15    折    1073.6    23.47

# %%
event_data = []
n = 0
for i in ['酸', '碱', '氧', '折', '空']:
    datai = data[data['Type']==i]
#     ad = (pd.DataFrame(datai))
#     sns.distplot(x=[1,2,3,4],y='Breakage',data=datai[i],palette='Set3')
#     print(ad)
#     print(type(data_fold ))
    sns.barplot(x=[1,2,3,4],y='Breakage',data = datai)

# %%
data_blank_mean = data_blank['Breakage'].mean()

# %%
sns.barplot(x=[1,2,3,4],y='Breakage',data=data_blank,palette='Set3')

# %%
data_blank['Breakage'].tolist()
# Out:
# [1216.0, 1139.6, 1234.2, 1287.0]

# %%
sns.set(style="whitegrid")
sns.barplot(xlist,y=[1216.0, 1139.6, 1234.2, 1287.0,data_blank_mean],palette='Set3')
plt.title('Blank_Group')

# %%
data_acid.Breakage.tolist()
# Out:
# [1069.6, 1204.3, 1122.0, 1201.7]

# %%
data_acid_mean = data_acid['Breakage'].mean()

# %%
ax2 = sns.barplot(xlist,y=[1069.6, 1204.3, 1122.0, 1201.7,data_acid_mean ])
plt.title('Acid Group')

# %%
data_acid['Percent'].tolist()
# Out:
# [24.7, 23.35, 23.55, 25.0]

# %%
a = data_acid['Percent'].tolist()
a.append(26.0)

# %%
plt.plot([1,2,3,4],data_acid['Percent'].tolist())

# %%
plt.plot([1,2,3,4,5],[1069.6, 1204.3, 1122.0, 1201.7,data_acid_mean ])
plt.xlim([1,5])
plt.ylim([0,1300])
# Out:
# (0, 1300)

# %%
plt.scatter(xlist,[1069.6, 1204.3, 1122.0, 1201.7,data_acid_mean ],s = 100)
plt.xlim([0,5])
plt.ylim([0,1300])
# Out:
# (0, 1300)

# %%
df['Type'].value_counts()
# Out:
# 碱    4
# 氧    4
# 折    4
# 酸    4
# 空    4
# Name: Type, dtype: int64

# %%
df['Type'].unique()
# Out:
# array(['酸', '碱', '氧', '折', '空'], dtype=object)

# %%
df['Type'].unique().tolist()
# Out:
# ['酸', '碱', '氧', '折', '空']

# %%
data.head()
# Out:
#    Type  Breakage  Percent Content
# 0  南京天元    1069.6    24.70       酸
# 1  南京天元    1204.3    23.35       酸
# 2  南京天元    1122.0    23.55       酸
# 3  南京天元    1201.7    25.00       酸
# 4  南京天元    1064.0    24.25       碱

# %%
ax = sns.violinplot(x="Content", y="Breakage", hue='Type',data=data)

# %%
ax5 = sns.barplot(x="Content", y="Breakage", hue='Type',data=data,order = ['空','酸', '碱', '氧', '折',  '温'],
                  palette='GnBu_r')
plt.xlabel('组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,1400)
# Out:
# (0, 1400)

# %%
# data['Content'].value_counts()

df['Content'].unique().tolist()
# Out:
# ['酸', '碱', '氧', '折', '空', '温']

# %%
ax5 = sns.boxplot(x="Content", y="Breakage", hue='Type',data=data,order = ['空','酸', '碱', '氧', '折',  '温'])

# %%
# 散点图+小提起图
# 两条命令一起运行就行了
ax = sns.barplot(x="Content", y="Breakage", hue='Type',data=data,order = ['空','酸', '碱', '氧', '折',  '温'],
             color=".8")
ax = sns.stripplot(x="Content", y="Breakage", hue='Type',data=data,order = ['空','酸', '碱', '氧', '折',  '温'])

# %%
# 强力保留率

# %%
plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Breakage',hue='Type',data=data_fold,palette="GnBu_r")

x=[1,2,3,4]
x1=[1,2,3,4]
y=data_fold['Breakage'][:4]
y1=data_fold['Breakage'][4:]
# zipped = zip(x,y)
# print(*zipped)
for x,y in zip(x,y):
    plt.text(x-1,y+20,'show:%i'%y,fontsize=10, ha='center', va= 'bottom')
# for x1,y1 in zip(x,y1):
#     plt.text(x1-1.5,y1+30,'show:%i'%y1,fontsize=10)
    


plt.xlabel('耐折组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,1300)
# plt.savefig('耐折组_N.jpg',dpi=400)
# Out:
# (0, 1300)

# %%
x=[1,2,3,4]
y1=data_fold['Breakage'][4:]
zipped = zip(x,y)
print(*zipped)
# Out:
# (1, 990.39999999999998) (2, 945.5) (3, 903.60000000000002) (4, 985.89999999999998)

# %%
x=data_fold['seq']
y=data_fold['Breakage']
zipped = zip(x,y)
print(*zipped)
# Out:
# ('1', 1099.5999999999999) ('2', 1168.4000000000001) ('3', 1147.4000000000001) ('4', 1073.5999999999999) ('1', 990.39999999999998) ('2', 945.5) ('3', 903.60000000000002) ('4', 985.89999999999998)

# %%
print(seq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-1f13b6c4a5b1> in <module>()
# ----> 1 print(seq)
#
# NameError: name 'seq' is not defined

# %%
plt.figure(figsize=(9,6))
plt.grid(linestyle="--")
ax1 = sns.barplot('seq','Breakage',hue='Type',data=data_fold,palette="GnBu_r")

x=data_fold['seq'].astype(int)
x1=data_fold['seq'].astype(int)
y=data_fold['Breakage'][:4]
y1=data_fold['Breakage'][4:]
# zipped = zip(x,y)
# print(*zipped)
for x,y in zip(x,y):
    plt.text(x-1.4,y+20,'%.1f'%y,fontsize=15)
for x1,y1 in zip(x1,y1):
    plt.text(x1-0.95,y1+45,'%.1f'%y1,fontsize=15)
    


plt.xlabel('耐折组',fontsize = 18)
plt.ylabel('断裂强力',fontsize = 18)
plt.xticks(fontsize = 18)
plt.yticks(fontsize=18)
ax1.legend(fontsize = 12)
plt.ylim(0,1400)
plt.savefig('耐折组_N.jpg',dpi=400)

# %%
x=data_fold['seq'].astype(int)
y=data_fold['Breakage']
y1=data_fold['Breakage']
zipped = zip(x,y)
print(*zipped)
# Out:
# (1, 1099.5999999999999) (2, 1168.4000000000001) (3, 1147.4000000000001) (4, 1073.5999999999999) (1, 990.39999999999998) (2, 945.5) (3, 903.60000000000002) (4, 985.89999999999998)
