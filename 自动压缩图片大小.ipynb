# %%
from PIL import Image
import os.path
import glob
import os

# %%
# def convertjpg(jpgfile,outdir,width=128,height=128):
#     img=Image.open(jpgfile)
#     try:
#         new_img=img.resize((width,height),Image.BILINEAR)   
#         new_img.save(os.path.join(outdir,os.path.basename(jpgfile)))
#     except Exception as e:
#         print(e)
# for jpgfile in glob.glob("E:\\img\\*.jpg"):
#     convertjpg(jpgfile,"E:\\lianhua")

# %%
os.chdir('/Users/lin/Desktop/A071 2019-2-22')
# !ls
# Out:
# 10089041    10089042    10089043-10

# %%
os.chdir('/Users/lin/Desktop/A071 2019-2-22/10089042/10089042-10')

# %%
# !ls
# Out:
# IMG_20190223_090625.jpg IMG_20190223_090759.jpg IMG_20190223_090917.jpg
# IMG_20190223_090656.jpg IMG_20190223_090822.jpg IMG_20190223_090922.jpg
# IMG_20190223_090718.jpg IMG_20190223_090835.jpg IMG_20190223_090927.jpg
# IMG_20190223_090736.jpg IMG_20190223_090853.jpg Thumbs.db

# %%
img_path = glob.glob("/Users/lin/Desktop/A071 2019-2-22/10089043-10/*.jpg".)
path_save = "/Users/lin/Desktop/2015-2017城市逐日空气质量数据"
for file in img_path:
#     name = os.path.join(path_save, file)
    im = Image.open(file)
    im.thumbnail((1920,1480))
    print(im.format, im.size, im.mode)
    im.save(name,'JPEG')
im.show()
# Out:
# JPEG (1920, 1080) RGB
# JPEG (1920, 1080) RGB
# JPEG (1920, 1080) RGB
# JPEG (1920, 1080) RGB
# JPEG (1920, 1080) RGB
# JPEG (1920, 1080) RGB
# JPEG (1920, 1080) RGB
# JPEG (1920, 1080) RGB
# JPEG (1920, 1080) RGB
# JPEG (1920, 1080) RGB
# JPEG (1920, 1080) RGB

# %%
os.chdir('/Users/lin/Desktop/A071 2019-2-22')
# !ls
# Out:
# 10089041                  10089042                  10089043-10________000000

# %%
def get_path():
    top = '/Users/lin/Desktop/A071 2019-2-22'
# os.walk(top,topdown=True,onerror=None)
    blank = []
    for (root, dirs, files) in os.walk(top,topdown=True):
        blank.append(root)
    return blank

# %%
len(select_path())
# Out:
# 36

# %%
def select_path():
    h = []
    blank = get_path()
    for i in range(len(blank)):
        if  len(blank[i])>50:
            h.append(blank[i])
        else:
            pass
    return h

# %%
# def get_file():
n=0
path = select_path()
for p in path:
#     os.chdir('{}'.format(p))
    for (root, dirs, files) in os.walk(p,topdown=True):
#         print(root)
#         print(files)
#         print('---'*10)
        os.chdir(root)
        img_path = glob.glob("*.jpg")
#         path_save = "/Users/lin/Desktop/2015-2017城市逐日空气质量数据"

#         print(img_path)
        for file in img_path:
#             name = os.path.join(path_save, file)
            im = Image.open(file)
            im.thumbnail((1220,880))
            n+=1
#             print(im.format, im.size, im.mode)
            print('第'+str(n)+'个图片已压缩')
          
            im.save(file,'JPEG')
# Out:
# 第1个图片已压缩
# 第2个图片已压缩
# 第3个图片已压缩
# 第4个图片已压缩
# 第5个图片已压缩
# 第6个图片已压缩
# 第7个图片已压缩
# 第8个图片已压缩
# 第9个图片已压缩
# 第10个图片已压缩
# 第11个图片已压缩
# 第12个图片已压缩
# 第13个图片已压缩
# 第14个图片已压缩
# 第15个图片已压缩
# 第16个图片已压缩
# 第17个图片已压缩
# 第18个图片已压缩
# 第19个图片已压缩
# 第20个图片已压缩
# 第21个图片已压缩
# 第22个图片已压缩
# 第23个图片已压缩
# 第24个图片已压缩
# 第25个图片已压缩
# 第26个图片已压缩
# 第27个图片已压缩
# 第28个图片已压缩
# 第29个图片已压缩
# 第30个图片已压缩
# 第31个图片已压缩
# 第32个图片已压缩
# 第33个图片已压缩
# 第34个图片已压缩
# 第35个图片已压缩
# 第36个图片已压缩
# 第37个图片已压缩
# 第38个图片已压缩
# 第39个图片已压缩
# 第40个图片已压缩
# 第41个图片已压缩
# 第42个图片已压缩
# 第43个图片已压缩
# 第44个图片已压缩
# 第45个图片已压缩
# 第46个图片已压缩
# 第47个图片已压缩
# 第48个图片已压缩
# 第49个图片已压缩
# 第50个图片已压缩
# 第51个图片已压缩
# 第52个图片已压缩
# 第53个图片已压缩
# 第54个图片已压缩
# 第55个图片已压缩
# 第56个图片已压缩
# 第57个图片已压缩
# 第58个图片已压缩
# 第59个图片已压缩
# 第60个图片已压缩
# 第61个图片已压缩
# 第62个图片已压缩
# 第63个图片已压缩
# 第64个图片已压缩
# 第65个图片已压缩
# 第66个图片已压缩
# 第67个图片已压缩
# 第68个图片已压缩
# 第69个图片已压缩
# 第70个图片已压缩
# 第71个图片已压缩
# 第72个图片已压缩
# 第73个图片已压缩
# 第74个图片已压缩
# 第75个图片已压缩
# 第76个图片已压缩
# 第77个图片已压缩
# 第78个图片已压缩
# 第79个图片已压缩
# 第80个图片已压缩
# 第81个图片已压缩
# 第82个图片已压缩
# 第83个图片已压缩
# 第84个图片已压缩
# ...
